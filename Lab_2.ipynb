# %% [markdown]
# <a href="https://colab.research.google.com/github/minhhuy211/ML_Learning/blob/master/Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab #2
# This lab is the first step to get farmilliar with some common Machine Learning libraries, named ***Pandas*** and ***Matlotlib***.
#
# *   **Deadline: 23:59, 18/03/2024**

# %% [markdown]
# #0. Mount Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd '/content/gdrive/MyDrive/Colab Notebooks'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/Colab Notebooks

# %% [markdown]
# #1. Import libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #2. Load dataset
#
# *   Load dataset (named ***student-dataset.csv***) using ***read_csv*** from pandas
# *   Then, display 10 last examples

# %%
data = pd.read_csv("student-dataset.csv")
data
# Out:
#       id               name               nationality gender  ethnic.group  \
# 0      0          Kiana Lor                     China      F           NaN
# 1      1     Joshua Lonaker  United States of America      M           NaN
# 2      2      Dakota Blanco  United States of America      F           NaN
# 3      3    Natasha Yarusso  United States of America      F           NaN
# 4      4     Brooke Cazares                    Brazil      F           NaN
# ..   ...                ...                       ...    ...           ...
# 302  302        Austin Haas  United States of America      M           NaN
# 303  303    Madison Fithian  United States of America      F           NaN
# 304  304  Zachary Mulvahill  United States of America      M           NaN
# 305  305   Eliana Michelsen  United States of America      F           NaN
# 306  306    Dane Whittemore                    Canada      M           NaN
#
# ...

# %% [markdown]
# #3. Show statistics of the given dataset

# %%
statistics = data.describe()
print(statistics)
# Out:
#                id  ethnic.group         age  english.grade  math.grade  \
# count  307.000000           0.0  307.000000     307.000000  307.000000
# mean   153.000000           NaN   21.964169       3.369707    3.414332
# std     88.767487           NaN    1.248013       0.538724    0.476839
# min      0.000000           NaN   19.000000       1.500000    2.100000
# 25%     76.500000           NaN   21.000000       3.100000    3.100000
# 50%    153.000000           NaN   22.000000       3.500000    3.500000
# 75%    229.500000           NaN   23.000000       3.800000    3.800000
# max    306.000000           NaN   26.000000       4.000000    4.000000
#
#        sciences.grade  language.grade  portfolio.rating  coverletter.rating  \
# count      307.000000      307.000000        307.000000          307.000000
# mean         3.446580        4.396417          3.986971            4.110749
# std          0.509081        0.996474          0.928749            0.823936
# ...

# %% [markdown]
# #4. Sort dataset by ***nationality***

# %%
# inplave = False: mặc định là sau khi sort sẽ không thay đổi vị trí thông tin trong dataframe
data.sort_values(by="nationality", ascending= True)
# Out:
#       id                   name               nationality gender  \
# 146  146       Juhaina al-Bilal                Bangladesh      F
# 285  285  Viridiana Ballesteros                    Brazil      F
# 271  271          Jasmine Lopez                    Brazil      F
# 4      4         Brooke Cazares                    Brazil      F
# 96    96         Mateo Cisneros                    Brazil      M
# ..   ...                    ...                       ...    ...
# 147  147           Siena Ingram  United States of America      F
# 149  149        Vincent Webster  United States of America      M
# 151  151         Patrick Carnes  United States of America      M
# 305  305       Eliana Michelsen  United States of America      F
# 153  153          Jenna Whitney  United States of America      F
#
#      ethnic.group  age  english.grade  math.grade  sciences.grade  \
# 146           NaN   20            3.9         3.9             3.9
# ...

# %% [markdown]
# #5. Group dataset by ***nationality*** and ***gender***

# %%
grouped = data.groupby(["nationality","gender"]).groups
print(grouped)
# Out:
# {('Bangladesh', 'F'): [146], ('Brazil', 'F'): [4, 135, 180, 226, 271, 285], ('Brazil', 'M'): [7, 96, 203], ('Canada', 'F'): [111, 139, 293], ('Canada', 'M'): [18, 121, 306], ('Canada', 'other'): [104], ('Chile', 'M'): [211], ('China', 'F'): [0, 162, 189, 218, 232], ('China', 'M'): [6, 21, 24, 61, 76, 176, 194, 214], ('Colombia', 'F'): [183], ('Colombia', 'M'): [94, 185, 244, 283], ('Cuba', 'F'): [70], ('Dominican Republic', 'F'): [29], ('Egypt', 'M'): [150], ('El Salvador', 'F'): [105], ('Germany', 'F'): [128], ('India', 'F'): [35, 41, 72, 175, 198], ('India', 'M'): [172, 215, 259], ('Japan', 'F'): [15, 37, 79, 95, 164, 200, 264, 280], ('Japan', 'M'): [20, 43, 46, 97, 99], ('Korea (Republic of)', 'F'): [68, 251], ('Korea (Republic of)', 'M'): [213], ('Mexico', 'F'): [39, 49, 82, 117, 125, 140, 145, 148, 169, 188, 237, 265, 296], ('Mexico', 'M'): [13, 50, 87, 112, 141, 178, 191, 210, 236, 268], ('Mexico', 'other'): [17], ('Morocco', 'F'): [187], ('Myanmar', 'F'): [85], ('Netherlands',
# ...

# %% [markdown]
# #6. Use scatter plot to represent the relationship between ***age*** and ***refletter.rating***
# Rememer adding titles, xlabel, ylabel, ... to the plot

# %%
x_value = data["age"]
y_value = data["refletter.rating"]

plt.scatter(x_value, y_value, s = 100, c = "blue")
plt.title("Age and Refletter.rating")
plt.xlabel("Age")
plt.ylabel("Refletter.rating")
plt.show()

# %% [markdown]
# #7. Use scatter plot to represent the relationship between ***age*** and ***sciences.grade***
# Rememer adding titles, xlabel, ylabel, ... to the plot

# %%
age = data["age"]
sciences = data["sciences.grade"]

plt.scatter(age, sciences, s = 100, c = "blue")
plt.title("Age and Sciences.grade")
plt.xlabel("Age")
plt.ylabel("sciences.grade")
plt.show()

# %% [markdown]
# #8. Use histogram plot to represent the distribution of ***Age***
# using bins=5

# %%
ages = data["age"]
range = (19, 26)
bins = 5
plt.hist(ages, bins, range, color = "green", histtype="bar", rwidth= 0.7)
plt.title('My histogram')
plt.xlabel('age')
plt.show()

# %% [markdown]
# #9. Create a data frame that computes the average of ages in each countries?
#
# Hint: Use groupby, select the age column and aggregate using mean.

# %%
average_age_by_country = data.groupby("nationality")["age"].mean()
# từ DataFrame (average_age_by_country) tạo một DataFrame mới đặt lại số thứ tự từ 1 -> n
average_age = pd.DataFrame(average_age_by_country).reset_index()
# Gán lại tên các cột mới
average_age.columns = ["Quốc gia", "Tuổi Trung Bình"]
print(average_age)
# Out:
#                     Quốc gia  Tuổi Trung Bình
# 0                 Bangladesh        20.000000
# 1                     Brazil        22.444444
# 2                     Canada        21.285714
# 3                      Chile        21.000000
# 4                      China        21.692308
# 5                   Colombia        21.200000
# 6                       Cuba        21.000000
# 7         Dominican Republic        22.000000
# 8                      Egypt        20.000000
# 9                El Salvador        23.000000
# 10                   Germany        20.000000
# 11                     India        21.625000
# 12                     Japan        22.384615
# 13       Korea (Republic of)        22.000000
# 14                    Mexico        21.833333
# 15                   Morocco        21.000000
# 16                   Myanmar        22.000000
# 17               Netherlands        21.000000
# 18                 Nicaragua        24.000000
# ...

# %% [markdown]
# #10. Create a dataframe including average of ***english.grade, math.grade, sciences.grade, language.grade, portfolio.rating, coverletter.rating, refletter.rating*** of each country

# %%
average_age_by_country = data.groupby("nationality")["age", "english.grade", "math.grade", "sciences.grade", "language.grade", "portfolio.rating", "coverletter.rating", "refletter.rating"].mean()
# từ DataFrame (average_age_by_country) tạo một DataFrame mới đặt lại số thứ tự từ 1 -> n
average_age = pd.DataFrame(average_age_by_country).reset_index()
# Gán lại tên các cột mới
print(average_age)
# Out:
#                  nationality        age  english.grade  math.grade  \
# 0                 Bangladesh  20.000000       3.900000    3.900000
# 1                     Brazil  22.444444       3.577778    3.377778
# 2                     Canada  21.285714       3.657143    3.014286
# 3                      Chile  21.000000       3.700000    3.700000
# 4                      China  21.692308       3.253846    3.784615
# 5                   Colombia  21.200000       3.540000    3.580000
# 6                       Cuba  21.000000       3.900000    2.800000
# 7         Dominican Republic  22.000000       3.400000    3.800000
# 8                      Egypt  20.000000       1.500000    3.500000
# 9                El Salvador  23.000000       3.300000    2.900000
# 10                   Germany  20.000000       3.200000    3.500000
# 11                     India  21.625000       3.000000    3.275000
# 12                     Japan  22.384615       3.330769    3.538462
# ...

# %% [markdown]
# #Finally,
# Remember renaming the notebook.
